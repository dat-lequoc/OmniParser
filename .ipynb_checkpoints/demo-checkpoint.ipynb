# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.3.61
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 185, in print_results
#     write_output("Summary: %s", dist.summary)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Summary: %s'
# Arguments: ('Ultralytics YOLO \U0001f680 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 186, in print_results
#     write_output("Home-page: %s", dist.homepage)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Home-page: %s'
# Arguments: ('https://ultralytics.com',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 187, in print_results
#     write_output("Author: %s", dist.author)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Author: %s'
# Arguments: ('',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 188, in print_results
#     write_output("Author-email: %s", dist.author_email)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Author-email: %s'
# Arguments: ('Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 189, in print_results
#     write_output("License: %s", dist.license)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'License: %s'
# Arguments: ('AGPL-3.0',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 190, in print_results
#     write_output("Location: %s", dist.location)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Location: %s'
# Arguments: ('C:\\Users\\quocd\\AppData\\Local\\uv\\cache\\archive-v0\\z8lkNhNwG6XGWGBlplZML\\Lib\\site-packages',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 195, in print_results
#     write_output("Requires: %s", ", ".join(dist.requires))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requires: %s'
# Arguments: ('matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, torch, torchvision, tqdm, ultralytics-thop',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f680' in position 26: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Scripts\pip.exe\__main__.py", line 8, in <module>
#     sys.exit(main())
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\main.py", line 80, in main
#     return command.main(cmd_args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 157, in main
#     return self._main(args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 231, in _main
#     return self._run_wrapper(level_number, options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\commands\show.py", line 196, in print_results
#     write_output("Required-by: %s", ", ".join(dist.required_by))
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\misc.py", line 374, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\quocd\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\quocd\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Required-by: %s'
# Arguments: ('',)

# %%
import torch

# Check CUDA availability
print(f"CUDA is available: {torch.cuda.is_available()}")

# If you want more details:
if torch.cuda.is_available():
    print(f"Current CUDA device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name()}")
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
# Out:
# CUDA is available: False

# %%
from utils import get_som_labeled_img, check_ocr_box, get_caption_model_processor, get_yolo_model
import torch
from ultralytics import YOLO
from PIL import Image
device = 'cuda'
model_path='weights/icon_detect_v1_5/model_v1_5.pt'

som_model = get_yolo_model(model_path)

som_model.to(device)
print('model to {}'.format(device))
# Out:
# [2025-01-14 16:48:45,907] [ WARNING] easyocr.py:80 - Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 10
#       6 model_path='weights/icon_detect_v1_5/model_v1_5.pt'
#       8 som_model = get_yolo_model(model_path)
# ---> 10 som_model.to(device)
#      11 print('model to {}'.format(device))
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:1340, in Module.to(self, *args, **kwargs)
#    1337         else:
#    1338             raise
# -> 1340 return self._apply(convert)
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\ultralytics\engine\model.py:882, in Model._apply(self, fn)
#     860 """
#     861 Applies a function to model tensors that are not parameters or registered buffers.
#     862
#    (...)
#     879     >>> model = model._apply(lambda t: t.cuda())  # Move model to GPU
#     880 """
#     881 self._check_is_pytorch_model()
# --> 882 self = super()._apply(fn)  # noqa
#     883 self.predictor = None  # reset predictor as device may have changed
#     884 self.overrides["device"] = self.device  # was str(self.device) i.e. device(type='cuda', index=0) -> 'cuda:0'
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\ultralytics\nn\tasks.py:260, in BaseModel._apply(self, fn)
#     250 def _apply(self, fn):
#     251     """
#     252     Applies a function to all the tensors in the model that are not parameters or registered buffers.
#     253
#    (...)
#     258         (BaseModel): An updated BaseModel object.
#     259     """
# --> 260     self = super()._apply(fn)
#     261     m = self.model[-1]  # Detect()
#     262     if isinstance(m, Detect):  # includes all Detect subclasses like Segment, Pose, OBB, WorldDetect
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:927, in Module._apply(self, fn, recurse)
#     923 # Tensors stored in modules are graph leaves, and we don't want to
#     924 # track autograd history of `param_applied`, so we have to use
#     925 # `with torch.no_grad():`
#     926 with torch.no_grad():
# --> 927     param_applied = fn(param)
#     928 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     930 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\nn\modules\module.py:1326, in Module.to.<locals>.convert(t)
#    1319     if convert_to_format is not None and t.dim() in (4, 5):
#    1320         return t.to(
#    1321             device,
#    1322             dtype if t.is_floating_point() or t.is_complex() else None,
#    1323             non_blocking,
#    1324             memory_format=convert_to_format,
#    1325         )
# -> 1326     return t.to(
#    1327         device,
#    1328         dtype if t.is_floating_point() or t.is_complex() else None,
#    1329         non_blocking,
#    1330     )
#    1331 except NotImplementedError as e:
#    1332     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~\AppData\Local\uv\cache\archive-v0\z8lkNhNwG6XGWGBlplZML\Lib\site-packages\torch\cuda\__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
# two choices for caption model: fine-tuned blip2 or florence2
import importlib
import utils
importlib.reload(utils)
from utils import get_som_labeled_img, check_ocr_box, get_caption_model_processor, get_yolo_model
# caption_model_processor = get_caption_model_processor(model_name="blip2", model_name_or_path="weights/icon_caption_blip2", device=device)
caption_model_processor = get_caption_model_processor(model_name="florence2", model_name_or_path="weights/icon_caption_florence", device=device)

# %%
som_model.device, type(som_model)

# %%
# reload utils
import importlib
import utils
importlib.reload(utils)
from utils import get_som_labeled_img, check_ocr_box, get_caption_model_processor, get_yolo_model

# image_path = 'imgs/google_page.png'
# image_path = 'imgs/windows_home.png'
# image_path = 'imgs/windows_multitab.png'
# image_path = 'imgs/omni3.jpg'
# image_path = 'imgs/ios.png'
# image_path = 'imgs/word.png'
image_path = 'screenshot.png'
# image_path = 'imgs/excel2.png'

image = Image.open(image_path)
image_rgb = image.convert('RGB')
print('image size:', image.size)

box_overlay_ratio = max(image.size) / 3200
draw_bbox_config = {
    'text_scale': 0.8 * box_overlay_ratio,
    'text_thickness': max(int(2 * box_overlay_ratio), 1),
    'text_padding': max(int(3 * box_overlay_ratio), 1),
    'thickness': max(int(3 * box_overlay_ratio), 1),
}
BOX_TRESHOLD = 0.05

import time
start = time.time()
ocr_bbox_rslt, is_goal_filtered = check_ocr_box(image_path, display_img = False, output_bb_format='xyxy', goal_filtering=None, easyocr_args={'paragraph': False, 'text_threshold':0.8}, use_paddleocr=True)
text, ocr_bbox = ocr_bbox_rslt
cur_time_ocr = time.time() 

dino_labled_img, label_coordinates, parsed_content_list = get_som_labeled_img(image_path, som_model, BOX_TRESHOLD = BOX_TRESHOLD, output_coord_in_ratio=True, ocr_bbox=ocr_bbox,draw_bbox_config=draw_bbox_config, caption_model_processor=caption_model_processor, ocr_text=text,use_local_semantics=True, iou_threshold=0.7, scale_img=False, batch_size=128)
cur_time_caption = time.time()

# %%
# plot dino_labled_img it is in base64
import base64
import matplotlib.pyplot as plt
import io
plt.figure(figsize=(15,15))

image = Image.open(io.BytesIO(base64.b64decode(dino_labled_img)))
plt.axis('off')

plt.imshow(image)
# print(len(parsed_content_list))

# %%
import pandas as pd
df = pd.DataFrame(parsed_content_list)
df['ID'] = range(len(df))

df

# %%
parsed_content_list

# %%
df.to_csv("omni_parser.csv")
